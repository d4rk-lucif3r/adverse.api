                 'Vedanta',
                 'FIR',
                 'SEBI',
                 'The Dynamic Duo of a Holistic Self-Care', 
                 'IamGujarat',
                 'Sensex today',
                 'Filmipop',
                 'Jharkhand', 
                 'Swachh Bharat', 
                 'The Good Earth', 
                 'Wild & Wacky', 
                 'The Economic Times', 
                 'Getty Images', 
                 'Ministry of Toursim', 
                 'Hot on Web']

      fp_org = [
                'Covid'

                 ]

      fp_loc = [


                 ]

      fp_date = [


                 ]
      

      keywords = ['money laundering', 
                  'money launder', 
                  'lauder the money', 
                  'money-mule', 
                  'money mule', 
                  'hawala', 'drug-trafficking', 'drug trafficking', 'terror', 'terror financing']
      # iterate through each string
      for string in tag.stripped_strings:

        for keyword in keywords:
          if keyword in str(string).lower():
            if keyword not in profile['keyword']:
              profile['keyword'] += keyword + ', '
        
        if 'HDFC' in str(string).lower():
          profile['hdfcpresent'] = 'Yes'


        if len(string) > 540:
          continue
        
        # name extration through spacy model
        doc = nlp_Name(str(string))
        
        # iterate through each entity present
        for count,ent in enumerate(doc.ents):
          # print(ent.label_, ':', ent.text)
          
          # find persons in text
          if ent.label_ == 'PERSON':
            
            # remove name if present in false positives
            if str(string) not in fp_name and (ent.text not in profile['name']):
              # print(str(string))
              profile['text'] = str(string)
              profile['name'] += ent.text + ', '
            else:
              # print('Persons entity:', ent.text, ':', ent.label_)
              pass
          
          # find persons in text
          elif ent.label_ == 'ORG':
            
            # remove name if present in false positives
            if str(string) not in fp_org and (ent.text not in profile['org']):
              profile['org'] += ent.text + ', '
            else:
              # print('Persons entity:', ent.text, ':', ent.label_)
              pass

          # find persons in text
          elif ent.label_ == 'GPE':
            
            # remove name if present in false positives
            if str(string) not in fp_loc and (ent.text not in profile['loc']):
              profile['loc'] += ent.text + ', '

          # find persons in text
          elif ent.label_ == 'DATE':
            
            # remove name if present in false positives
            if str(string) not in fp_date and (ent.text not in profile['date']) and (not (ent.text).isalpha()) and (not (ent.text).isdigit())and (not profile['date']):
              try:
                profile['date'] += str(parse(ent.text)) + ', '
              except:
                pass
          
      
      profile['sources'] = response.url

      yield profile

# %%
# %cd tutorial/
# !scrapy crawl test_india -O test_india.json

# %%
# !rm test_india.json

# %%
# %cd /content/tutorial/
# !ls

# %%
# %cd /content/tutorial/tutorial/
# !ls

# %%
import pandas as pd

# %%
df = pd.read_json('test_india.json')

# %%
df.head()

# %%
df.shape

# %%
import numpy as np

# replace empty string na values
df.replace(to_replace='', value=np.nan, inplace=True)

# %%
# check keywords in all the rows
null_keywords = df[df['keyword'].isna()]

# %%
null_keywords.index.tolist()

# %%
print(null_keywords.loc[34, 'sources'])

# %%
df.drop([37, 40, 41, 42, 43, 44, 48, 52], inplace=True)

# %%
df.loc[1, 'keyword'] = 'black money'
df.loc[13, 'keyword'] = 'drug traffickers'
df.loc[23, 'keyword'] = 'drug trafficking'
df.loc[25, 'keyword'] = 'trafficking'
df.loc[29, 'keyword'] = 'drug traffickers'
df.loc[31, 'keyword'] = 'drug transit'
df.loc[34, 'keyword'] = 'drug delivery'
# df.loc[37, 'keyword'] = 'delete'
# df.loc[40, 'keyword'] = 'delete'
# df.loc[41, 'keyword'] = 'delete'
# df.loc[42, 'keyword'] = 'delete'
# df.loc[43, 'keyword'] = 'delete'
# df.loc[44, 'keyword'] = 'delete'
# df.loc[48, 'keyword'] = 'delete'
# df.loc[52, 'keyword'] = 'delete'
df.loc[59, 'keyword'] = 'money laundering'

# %%
df.drop(['text', 
         'facebook_link', 
         'twitter_link', 
         'other_weblinks', 
         'image_link'], axis=1, inplace=True)

# %%
df.head()

# %%
df.columns

# %%
df.columns = ['Person Name mentioned in the news', 
              'Organization Name mentioned in the news', 
              'City/ State mentioned under the news', 
              'Key word Used for identify the article', 
              'Web link of news',
              'HDFC Bank Name under News / Article', 
              'Article Date']

# %%
df.head()

# %%
df['Source of Info'] = 'News Paper'

# %%
df['Source Name'] = 'Economic Times'

# %%
import numpy as np

df['City of News Paper'] = np.nan

# %%
# strip ending comma, spaces
df['Person Name mentioned in the news'] = df['Person Name mentioned in the news'].apply(lambda x: x.strip(', '))
df['Organization Name mentioned in the news'] = df['Organization Name mentioned in the news'].apply(lambda x: x.strip(', '))
df['City/ State mentioned under the news'] = df['City/ State mentioned under the news'].apply(lambda x: x.strip(', '))
df['Key word Used for identify the article'] = df['Key word Used for identify the article'].apply(lambda x: x.strip(', '))
df['HDFC Bank Name under News / Article'] = df['HDFC Bank Name under News / Article'].apply(lambda x: x.strip(', '))

# %%
df['HDFC Bank Name under News / Article'][0]

# %%
df.columns

# %%
df.shape

# %%
df.columns

# %%
df.to_json('economic.json', orient='records', lines=True)

# %% [markdown]
# Named Entity Recognition: Name extraction using spacy en_core_web_trf
# ===
# ## 1. council ministers
# * https://www.india.gov.in/my-government/whos-who/council-ministers

# %%
# !pip install spacy --upgrade

# %%
# !python -m spacy download en_core_web_trf

# %%
# !pip install Scrapy --upgrade

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content/
# !ls tutorial/tutorial/spiders

# %%
# %%writefile tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'name']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://www.india.gov.in/my-government/whos-who/council-ministers',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
      # text data of entire webpage
      soup = BeautifulSoup(response.text, 'html.parser') # parse
      # extract body from it
      soup = soup.body # scrape.parse_soup

      # if len(soup.findAll('td'))==0:
      #   blocks = soup.findAll('div')
      if len(soup.findAll('th'))==0: # this is the format
        blocks = soup.findAll('td') # of council of ministers webpage structure
      else:
        blocks = soup.findAll('tr')

      # if len(soup.findAll('td'))==0:
      #   blocks = soup.findAll('div')
      # elif len(soup.findAll('th'))==0: # this is the format
      #   blocks = soup.findAll('td') # of council of ministers webpage structure
      # else:
      #   blocks = soup.findAll('tr')
      
      blocks = list(set(blocks))
      
      for block in blocks:
        # save into a dictionary
        profile = {'text': '', 'name': ''}
        content = block.get_text(separator=' ', strip=True).replace('\n', ' ').replace('\t', ' ')
        content = unidecode(content)
        print(content)
        profile['text'] += content + ' '
        
        name=''
        doc = nlp_Name(content)
        # profile['text'] = content
        for count,ent in enumerate(doc.ents):
          if ent.label_ == 'PERSON':
            profile['name'] +=ent.text+' '
            # if count==0:
              # break
        
        writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %%
df.name.unique()

# %% [markdown]
# ---------------------Reset runtime --------------------

# %% [markdown]
# ## 2. Chiefs of Armed forces
# * https://www.india.gov.in/my-government/whos-who/chiefs-armed-forces
# * modify the structure of blocks

# %%
# !pip install spacy --upgrade

# %% [markdown]
# ----------------- Restart Runtime -------------

# %%
# !python -m spacy download en_core_web_trf

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !pip install Scrapy --upgrade

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content/
# !ls tutorial/tutorial/spiders

# %%
# %%writefile /content/tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'name']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://www.india.gov.in/my-government/whos-who/chiefs-armed-forces',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        # text data of entire webpage
        soup = BeautifulSoup(response.text, 'html.parser') # parse
        # extract body from it
        soup = soup.body # scrape.parse_soup
        
        text = soup.get_text()
        blocks = text.split('   ')
      
        # if len(soup.findAll('td'))==0:
        #     blocks = soup.findAll('div')
        # elif len(soup.findAll('th'))==0:
        #     blocks = soup.findAll('td')
        # else:
        #     blocks = soup.findAll('tr')
        
        blocks = list(set(blocks))
        
        for block in blocks:
            # save into a dictionary
            profile = {'text': '', 'name': ''}
            # content = block.get_text(separator=' ', strip=True) # .replace('\n', ' ').replace('\t', ' ')
            content = str(block).strip()
            content = unidecode(content)
            print(content)
            profile['text'] += str(content) + ' '
            
            name=''
            doc = nlp_Name(content)
            # profile['text'] = content
            for count,ent in enumerate(doc.ents):
                if ent.label_ == 'PERSON':
                    # profile['name'] +=ent.text+' '
                    # print(profile['name'])
            
            writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %%
df.name.unique().tolist()

# %% [markdown]
# ##3. Chief Justices
# * https://main.sci.gov.in/chief-justice-judges
# * modify the structure of web scraping response.text

# %%
# !pip install spacy --upgrade

# %% [markdown]
# ----------------- Restart Runtime -------------

# %%
# !python -m spacy download en_core_web_trf

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !pip install Scrapy --upgrade

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content
# !ls tutorial/tutorial/spiders

# %%
# %%writefile tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'name']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://main.sci.gov.in/chief-justice-judges',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
      # text data of entire webpage
      soup = BeautifulSoup(response.text, 'html.parser') # parse
      # extract body from it
      soup = soup.body # scrape.parse_soup
      
      if len(soup.findAll('td'))==0:
        blocks = soup.findAll('div')
      elif len(soup.findAll('th'))==0:
        blocks = soup.findAll('td')
      else:
        blocks = soup.findAll('tr')
      
      blocks = list(set(blocks))
      
      for block in blocks:
        # save into a dictionary
        profile = {'text': '', 'name': ''}
        content = block.get_text(separator=' ', strip=True).replace('\n', ' ').replace('\t', ' ')
        content = unidecode(content)
        print(content)
        profile['text'] += content + ' '
        
        name=''
        doc = nlp_Name(content)
        # profile['text'] = content
        for count,ent in enumerate(doc.ents):
          if ent.label_ == 'PERSON':
            profile['name'] +=ent.text+' '
            # if count==0:
              # break
        
        writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %% [markdown]
# ## 4. President
# * https://www.india.gov.in/my-government/whos-who/president
# * modify the structure of web scraping response.text

# %%
# !pip install spacy --upgrade

# %%
# !python -m spacy download en_core_web_trf

# %%
# !pip install Scrapy --upgrade

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content/
# !ls tutorial/tutorial/spiders

# %%
# %%writefile tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'name']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://www.india.gov.in/my-government/whos-who/president',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
      # text data of entire webpage
      soup = BeautifulSoup(response.text, 'html.parser') # parse
      # extract body from it
      soup = soup.body # scrape.parse_soup
      
      if len(soup.findAll('td'))==0:
        blocks = soup.findAll('div')
      elif len(soup.findAll('th'))==0:
        blocks = soup.findAll('td')
      else:
        blocks = soup.findAll('tr')
      
      blocks = list(set(blocks))
      
      for block in blocks:
        # save into a dictionary
        profile = {'text': '', 'name': ''}
        content = block.get_text(separator=' ', strip=True).replace('\n', ' ').replace('\t', ' ')
        content = unidecode(content)
        print(content)
        profile['text'] += content + ' '
        
        name=''
        doc = nlp_Name(content)
        # profile['text'] = content
        for count,ent in enumerate(doc.ents):
          if ent.label_ == 'PERSON':
            profile['name'] +=ent.text+' '
            # if count==0:
              # break
        
        writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %% [markdown]
# Named Entity Recognition: Designation extraction using spacy en_core_web_trf
# ===
# ## 1. council ministers
# * https://www.india.gov.in/my-government/whos-who/council-ministers

# %%
# !pip install spacy --upgrade

# %%
# !python -m spacy download en_core_web_trf

# %%
# !pip install Scrapy --upgrade

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content/
# !ls tutorial/tutorial/spiders

# %%
# %%writefile tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'designation']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://www.india.gov.in/my-government/whos-who/council-ministers',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
      # text data of entire webpage
      soup = BeautifulSoup(response.text, 'html.parser') # parse
      # extract body from it
      soup = soup.body # scrape.parse_soup
      
      if len(soup.findAll('td'))==0:
        blocks = soup.findAll('div')
      elif len(soup.findAll('th'))==0:
        blocks = soup.findAll('td')
      else:
        blocks = soup.findAll('tr')
      
      blocks = list(set(blocks))
      
      for block in blocks:
        # save into a dictionary
        profile = {'text': '', 'name': ''}
        content = block.get_text(separator=' ', strip=True).replace('\n', ' ').replace('\t', ' ')
        content = unidecode(content)
        print(content)
        profile['text'] += content + ' '
        
        name=''
        doc = nlp_Name(content)
        # profile['text'] = content
        for count,ent in enumerate(doc.ents):
          if ent.label_ == 'ORG':
            profile['designation'] +=ent.text+' '
            # if count==0:
              # break
        
        writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %% [markdown]
# UAE:
# ====
# ## 1. Members of the Cabinet

# %%
# !pip install spacy --upgrade

# %%
# !python -m spacy download en_core_web_trf

# %%
# !pip install Scrapy --upgrade

# %%
# !pip install unidecode

# %% [markdown]
# --------------- Restart Runtime ----------------

# %%
# !scrapy startproject tutorial

# %%
# !ls

# %%
# %cd /content/
# !ls tutorial/tutorial/spiders

# %%
# %%writefile tutorial/tutorial/spiders/test_india.py
import scrapy
import os
import csv

from bs4 import BeautifulSoup
from unidecode import unidecode
import spacy

nlp_Name = spacy.load("en_core_web_trf") # spacy.load(OUTPUT1)

csv_columns = ['text', 'name']

# defining new variable passing two parameters
writer = csv.DictWriter(open(os.path.abspath(os.path.join(os.getcwd(), 'test_results1.csv')), 'w'), fieldnames=csv_columns)

# writeheader() method to the write to the file object
writer.writeheader()

class IndiaTestSpider(scrapy.Spider):
    name = "test_india"

    def start_requests(self):
        urls = [
            'https://uaecabinet.ae/en/cabinet-members',
            # 'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
      # text data of entire webpage
      soup = BeautifulSoup(response.text, 'html.parser') # parse
      # extract body from it
      soup = soup.body # scrape.parse_soup
      
      if len(soup.findAll('td'))==0:
        blocks = soup.findAll('div')
      elif len(soup.findAll('th'))==0: # this is the format
        blocks = soup.findAll('td') # of council of ministers webpage structure
      else:
        blocks = soup.findAll('tr')
      
      blocks = list(set(blocks))
      
      for block in blocks:
        # save into a dictionary
        profile = {'text': '', 'name': ''}
        content = block.get_text(separator=' ', strip=True).replace('\n', ' ').replace('\t', ' ')
        content = unidecode(content)
        print(content)
        profile['text'] += content + ' '
        
        name=''
        doc = nlp_Name(content)
        # profile['text'] = content
        for count,ent in enumerate(doc.ents):
          if ent.label_ == 'PERSON':
            profile['name'] +=ent.text+' '
            # if count==0:
              # break
        
        writer.writerow(profile)

# %%
# %cd tutorial/
# !scrapy crawl test_india

# %%
import pandas as pd

# %%
df = pd.read_csv('test_results1.csv')

# %%
df.head()

# %%
df.name.unique()
